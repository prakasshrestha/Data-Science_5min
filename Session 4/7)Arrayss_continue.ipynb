# %%
for i in arr2:
  print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
x = np.where(arr2 == 20)
print(x)
# Out:
# (array([1]),)

# %%
x = np.where(arr2 == 50)
print(x)
# Out:
# (array([4]),)

# %%
x = np.where(arrr == 2)
print(x)
# Out:
# (array([1, 4, 7]),)

# %%
arraysort = np.array([2,1,5,3,7,5,9,8,5,7,3])

# %%
np.sort(arraysort)
# Out:
# array([1, 2, 3, 3, 5, 5, 5, 7, 7, 8, 9])

# %%
np.insert(arr2,5,60)
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
np.insert(arraysort,11,10)
# Out:
# array([ 2,  1,  5,  3,  7,  5,  9,  8,  5,  7,  3, 10])

# %%
np.insert(arraysort,0,100)
# Out:
# array([100,   2,   1,   5,   3,   7,   5,   9,   8,   5,   7,   3])

# %%
np.delete(arraysort,0)
# Out:
# array([1, 5, 3, 7, 5, 9, 8, 5, 7, 3])

# %%
arraysort
# Out:
# array([2, 1, 5, 3, 7, 5, 9, 8, 5, 7, 3])

# %%
arrr1 = np.insert(arr2,5,60)

# %%
arrr1
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
arr2
# Out:
# array([10, 20, 30, 40, 50])

# %%
index = [0,1,2]

# %%
arrr2 = np.delete(arr2,index)

# %%
arrr2
# Out:
# array([40, 50])

# %%
arr2
# Out:
# array([10, 20, 30, 40, 50])

# %%
np.flip(arr2)
# Out:
# array([50, 40, 30, 20, 10])

# %%
arr2
# Out:
# array([10, 20, 30, 40, 50])

# %%
arrflip = np.flip(arr2)

# %%
arrflip
# Out:
# array([50, 40, 30, 20, 10])

# %%
arr2[0] = 100

# %%
arr2
# Out:
# array([100,  20,  30,  40,  50])

# %%
arr2.sort()

# %%
arr2
# Out:
# array([ 20,  30,  40,  50, 100])

# %%
np.append(arr2,1000)
# Out:
# array([  20,   30,   40,   50,  100, 1000])

# %%
arr2
# Out:
# array([ 20,  30,  40,  50, 100])

# %%
arr2.append(1000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/m0/4t6ggwz51774ll_46v6qgz3h0000gn/T/ipykernel_37101/448774566.py in <module>
# ----> 1 arr2.append(1000)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'
